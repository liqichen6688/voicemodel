# %%
import numpy
import matplotlib.plot as plot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e40d0739dc3c> in <module>()
#       1 import numpy
# ----> 2 import matplotlib.plot as plot
#
# ModuleNotFoundError: No module named 'matplotlib.plot'

# %%
import matplotlib.pyplot as plot

# %%
import numpy as np

# %%
a = np.load('accu0.001.npy')

# %%
a
# Out:
# array([0.3468, 0.3728, 0.3452, 0.3408, 0.3292, 0.3664, 0.33  , 0.3572,
#        0.3684, 0.3472, 0.3456, 0.3256, 0.3552, 0.3388, 0.344 , 0.3636,
#        0.358 , 0.3448, 0.364 , 0.3436, 0.3748, 0.3508, 0.3536, 0.3456,
#        0.356 , 0.3664, 0.3512, 0.3732, 0.3724, 0.366 , 0.376 , 0.3612,
#        0.3784, 0.3848, 0.3636, 0.3812, 0.3852, 0.3716, 0.3836, 0.3804,
#        0.388 , 0.3744, 0.3856, 0.3872, 0.392 , 0.3916, 0.3724, 0.3844,
#        0.3716, 0.3856, 0.3804, 0.364 , 0.3756, 0.3952, 0.374 , 0.3836,
#        0.3984, 0.3928, 0.406 , 0.3764])

# %%
plot.plot(a)

# %%
b = np.load('loss0.001.npy')

# %%
plot.plot(b)

# %%
c = np.load('test0.001.npy')

# %%
plot.plot(c)
